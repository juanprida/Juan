# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
population = pd.read_csv('C:/Users/SMAPRJ/Desktop/Juan/The Economist/population.csv')

# %%
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70080 entries, 0 to 70079
# Data columns (total 8 columns):
# Year                 70080 non-null int64
# District.Code        70080 non-null int64
# District.Name        70080 non-null object
# Neighborhood.Code    70080 non-null int64
# Neighborhood.Name    70080 non-null object
# Gender               70080 non-null object
# Age                  70080 non-null object
# Number               70080 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 4.3+ MB

# %%
population = population.replace('5-9','05-9')

# %%
population['Year'].value_counts()
# Out:
# 2017    14016
# 2016    14016
# 2015    14016
# 2014    14016
# 2013    14016
# Name: Year, dtype: int64

# %%
population.head()
# Out:
#    Year  District.Code District.Name  Neighborhood.Code  \
# 0  2017              1  Ciutat Vella                  1
# 1  2017              1  Ciutat Vella                  2
# 2  2017              1  Ciutat Vella                  3
# 3  2017              1  Ciutat Vella                  4
# 4  2017              2      Eixample                  5
#
#                        Neighborhood.Name Gender  Age  Number
# 0                               el Raval   Male  0-4     224
# 1                         el Barri Gòtic   Male  0-4      50
# 2                         la Barceloneta   Male  0-4      43
# 3  Sant Pere, Santa Caterina i la Ribera   Male  0-4      95
# 4                          el Fort Pienc   Male  0-4     124

# %%
population.describe()
# Out:
#                Year  District.Code  Neighborhood.Code        Number
# count  70080.000000   70080.000000       70080.000000  70080.000000
# mean    2015.000000       6.246575          37.000000    114.844720
# std        1.414224       2.788356          21.071458     96.540389
# min     2013.000000       1.000000           1.000000      0.000000
# 25%     2014.000000       4.000000          19.000000     43.000000
# 50%     2015.000000       7.000000          37.000000     92.000000
# 75%     2016.000000       8.000000          55.000000    162.000000
# max     2017.000000      10.000000          73.000000    777.000000

# %%
population_2017 = population.loc[population['Year']==2017].sort_values('Age')

# %%
print(population_2017)
# Out:
#        Year  District.Code        District.Name  Neighborhood.Code  \
# 0      2017              1         Ciutat Vella                  1
# 7126   2017              8           Nou Barris                 46
# 7127   2017              8           Nou Barris                 47
# 7128   2017              8           Nou Barris                 48
# 7129   2017              8           Nou Barris                 49
# 7130   2017              8           Nou Barris                 50
# 7131   2017              8           Nou Barris                 51
# 7132   2017              8           Nou Barris                 52
# 7133   2017              8           Nou Barris                 53
# 7125   2017              8           Nou Barris                 45
# 7134   2017              8           Nou Barris                 54
# 7136   2017              8           Nou Barris                 56
# 7137   2017              9          Sant Andreu                 57
# 7138   2017              9          Sant Andreu                 58
# 7139   2017              9          Sant Andreu                 59
# 7140   2017              9          Sant Andreu                 60
# 7141   2017              9          Sant Andreu                 61
# 7142   2017              9          Sant Andreu                 62
# 7143   2017              9          Sant Andreu                 63
# 7135   2017              8           Nou Barris                 55
# 7124   2017              8           Nou Barris                 44
# 7123   2017              7       Horta-Guinardó                 43
# 7122   2017              7       Horta-Guinardó                 42
# 7102   2017              5  Sarrià-Sant Gervasi                 22
# 7103   2017              5  Sarrià-Sant Gervasi                 23
# 7104   2017              5  Sarrià-Sant Gervasi                 24
# 7108                      Vallcarca i els Penitents  Female   0-4      68
# ...                                             ...     ...   ...     ...
# 6997                                          Navas    Male  >=95      11
# 6998                     el Camp de l'Arpa del Clot    Male  >=95      27
# 6999                                        el Clot    Male  >=95      15
# 7000              el Parc i la Llacuna del Poblenou    Male  >=95       6
# 7001                  la Vila Olímpica del Poblenou    Male  >=95       1
# 7002                                    el Poblenou    Male  >=95      13
# 7003   Diagonal Mar i el Front Marítim del Poblenou    Male  >=95       7
# 7004                          el Besòs i el Maresme    Male  >=95      10
# 7005                        Provençals del Poblenou    Male  >=95       3
# 6990                                       Vallbona    Male  >=95       3
# 14014                      Sant Martí de Provençals  Female  >=95      57
# 6989                               Ciutat Meridiana    Male  >=95       2
# 6987                               la Trinitat Nova    Male  >=95       1
# 6972                                   la Teixonera    Male  >=95       3
# 6973                       Sant Genís dels Agudells    Male  >=95       3
# 6974                                        Montbau    Male  >=95       9
# 6975                               la Vall d'Hebron    Male  >=95       1
# 6976                                       la Clota    Male  >=95       0
# 6977                                          Horta    Male  >=95      21
# 6978                  Vilapicina i la Torre Llobeta    Male  >=95      17
# 6979                                          Porta    Male  >=95      16
# 6980                            el Turó de la Peira    Male  >=95      12
# 6981                                    Can Peguera    Male  >=95       0
# 6982                                   la Guineueta    Male  >=95       8
# 6983                                      Canyelles    Male  >=95       1
# 6984                                   les Roquetes    Male  >=95       4
# 6985                                         Verdun    Male  >=95       9
# 6986                                 la Prosperitat    Male  >=95      14
# 6988                                     Torre Baró    Male  >=95       0
# 14015                           la Verneda i la Pau  Female  >=95      54
#
# [14016 rows x 8 columns]

# %%
population_2017_by_age=(population_2017.groupby(['Age'])['Number'].sum())

population_2017_by_age = population_2017_by_age.reset_index().replace('5-9','05-9').sort_values('Age')
print(population_2017_by_age)
# Out:
#       Age  Number
# 0     0-4   68402
# 1    05-9   69309
# 2   10-14   67575
# 3   15-19   65953
# 4   20-24   79062
# 5   25-29  106489
# 6   30-34  122353
# 7   35-39  134575
# 8   40-44  133557
# 9   45-49  118332
# 10  50-54  113041
# 11  55-59  102949
# 12  60-64   90465
# 13  65-69   86264
# 14  70-74   77501
# 15  75-79   59962
# 16  80-84   59453
# 17  85-89   41136
# 18  90-94   19016
# 19   >=95    5415

# %%
g = sns.barplot(x= population_2017_by_age['Age'], y = population_2017_by_age['Number'], orient='v', palette="hls")
g.set_title("Barcelona - Personas por edad", fontsize=20)
sns.set(rc={'figure.figsize':(17,7)})
g.set_xlabel("Rango edad", fontsize=20)
g.set_ylabel("Personas", fontsize=20)
# Out:
# Text(0, 0.5, 'Personas')

# %%
aaa = population_2017.pivot_table(index='District.Name', columns='Age', values='Number', aggfunc='sum')
h = sns.heatmap(aaa, cmap="YlGnBu")
h.set_title("Donde viven los jóvenes en Barcelona?", fontsize=22)
h.set_xlabel("Edad",fontsize=18)
h.set_ylabel("Distrito", fontsize=18)
# Out:
# Text(129.453125, 0.5, 'Distrito')

# %%
aaa = population_2017.pivot_table(index='Neighborhood.Name', columns='Age', values='Number', aggfunc='sum')
h = sns.heatmap(aaa, cmap="YlGnBu")
h.set_title("Donde viven los jóvenes en Barcelona?", fontsize=50)
h.set_xlabel("Edad",fontsize=38)
h.set_ylabel("Barrio", fontsize=38)
sns.set(rc={'figure.figsize':(30,100)})

# %%
aaa = population_2017.loc[population_2017['Gender']=='Female'].pivot_table(index='District.Name', columns='Age', values='Number', aggfunc='sum')
h = sns.heatmap(aaa, cmap="viridis")
h.set_title("Donde viven las mujeres en Barcelona?", fontsize=22)
h.set_xlabel("Edad",fontsize=18)
h.set_ylabel("Distrito", fontsize=18)
# Out:
# Text(129.453125, 0.5, 'Distrito')

# %%
aaa = population_2017.loc[population_2017['Gender']=='Female'].loc[population_2017['District.Name']=='Eixample'].pivot_table(index='Neighborhood.Name', columns='Age', values='Number', aggfunc='sum')
h = sns.heatmap(aaa, cmap='coolwarm')
h.set_title("Donde viven las mujeres en Eixample, Barcelona?", fontsize=22)
h.set_xlabel("Edad",fontsize=18)
h.set_ylabel("Barrios en Eixample", fontsize=18)
# Out:
# Text(129.453125, 0.5, 'Barrios en Eixample')

# %%
population_25_29 = (population.loc[population['Age']=='25-29'].groupby(['Year','District.Name','Neighborhood.Name'])['Number'].sum()).reset_index()
print(population_25_29)
# Out:
#      Year        District.Name                             Neighborhood.Name  \
# 0    2013         Ciutat Vella         Sant Pere, Santa Caterina i la Ribera
# 1    2013         Ciutat Vella                                el Barri Gòtic
# 2    2013         Ciutat Vella                                      el Raval
# 3    2013         Ciutat Vella                                la Barceloneta
# 4    2013             Eixample                                   Sant Antoni
# 5    2013             Eixample                                 el Fort Pienc
# 6    2013             Eixample               l'Antiga Esquerra de l'Eixample
# 7    2013             Eixample                        la Dreta de l'Eixample
# 8    2013             Eixample                la Nova Esquerra de l'Eixample
# 9    2013             Eixample                            la Sagrada Família
# 10   2013               Gràcia                     Vallcarca i els Penitents
# 11   2013               Gràcia            el Camp d'en Grassot i Gràcia Nova
# 12   2013               Gràcia                                       el Coll
# 13   2013               Gràcia                                      la Salut
# 14   2013               Gràcia                             la Vila de Gràcia
# 15   2013       Horta-Guinardó                                      Can Baró
# 16   2013       Horta-Guinardó                                         Horta
# 17   2013       Horta-Guinardó                                       Montbau
# 18   2013       Horta-Guinardó                      Sant Genís dels Agudells
# 19   2013       Horta-Guinardó                              el Baix Guinardó
# 20   2013       Horta-Guinardó                                     el Carmel
# 21   2013       Horta-Guinardó                                   el Guinardó
# 22   2013       Horta-Guinardó                                      la Clota
# 23   2013       Horta-Guinardó                          la Font d'en Fargues
# 24   2013       Horta-Guinardó                                  la Teixonera
# 25   2013       Horta-Guinardó                              la Vall d'Hebron
# 26   2013            Les Corts                                     Pedralbes
# 27   2013            Les Corts                    la Maternitat i Sant Ramon
# 28   2013            Les Corts                                     les Corts
# 29   2013           Nou Barris                                   Can Peguera
# ..    ...                  ...                                           ...
# 335  2017          Sant Andreu                                         Navas
# 336  2017          Sant Andreu                                   Sant Andreu
# 337  2017          Sant Andreu                                 el Bon Pastor
# 338  2017          Sant Andreu                      el Congrés i els Indians
# 339  2017          Sant Andreu                                    la Sagrera
# 340  2017          Sant Andreu                             la Trinitat Vella
# 341  2017           Sant Martí  Diagonal Mar i el Front Marítim del Poblenou
# 342  2017           Sant Martí                       Provençals del Poblenou
# 343  2017           Sant Martí                      Sant Martí de Provençals
# 344  2017           Sant Martí                         el Besòs i el Maresme
# 345  2017           Sant Martí                    el Camp de l'Arpa del Clot
# 346  2017           Sant Martí                                       el Clot
# 347  2017           Sant Martí             el Parc i la Llacuna del Poblenou
# 348  2017           Sant Martí                                   el Poblenou
# 349  2017           Sant Martí                           la Verneda i la Pau
# 350  2017           Sant Martí                 la Vila Olímpica del Poblenou
# 351  2017       Sants-Montjuïc                                   Hostafrancs
# 352  2017       Sants-Montjuïc                                         Sants
# 353  2017       Sants-Montjuïc                                 Sants - Badal
# 354  2017       Sants-Montjuïc                                  el Poble Sec
# 355  2017       Sants-Montjuïc                                    la Bordeta
# 356  2017       Sants-Montjuïc                         la Font de la Guatlla
# 357  2017       Sants-Montjuïc                             la Marina de Port
# 358  2017       Sants-Montjuïc                    la Marina del Prat Vermell
# 359  2017  Sarrià-Sant Gervasi                        Sant Gervasi - Galvany
# 360  2017  Sarrià-Sant Gervasi                    Sant Gervasi - la Bonanova
# 361  2017  Sarrià-Sant Gervasi                                        Sarrià
# 362  2017  Sarrià-Sant Gervasi         Vallvidrera, el Tibidabo i les Planes
# 363  2017  Sarrià-Sant Gervasi                          el Putxet i el Farró
# 364  2017  Sarrià-Sant Gervasi                               les Tres Torres
#
#      Number
# 0      2414
# 1      1962
# 2      5032
# 3      1482
# 4      2836
# 5      2395
# 6      3413
# 7      3174
# 8      4474
# 9      3906
# 10      945
# 11     2337
# 12      413
# 13      894
# 14     4268
# 15      554
# 16     1558
# 17      240
# 18      355
# 19     1626
# 20     1919
# 21     2263
# 22       27
# 23      472
# 24      722
# 25      288
# 26      684
# 27     1705
# 28     3063
# 29      112
# ..      ...
# 335    1271
# 336    2954
# 337     632
# 338     742
# 339    1696
# 340     659
# 341     509
# 342    1235
# 343    1330
# 344    1516
# 345    2519
# 346    1631
# 347    1079
# 348    1754
# 349    1500
# 350     447
# 351    1241
# 352    2885
# 353    1695
# 354    3041
# 355    1181
# 356     724
# 357    1746
# 358      85
# 359    2788
# 360    1442
# 361    1272
# 362     222
# 363    1800
# 364     876
#
# [365 rows x 4 columns]

# %%
sns.set_style("white")
g = sns.relplot(x="Year", y="Number", hue='Neighborhood.Name',kind="line", col_wrap=4, col='District.Name', linewidth=5,  dashes=True, markers=True, data=population_25_29).despine()
